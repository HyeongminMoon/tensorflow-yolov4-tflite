# %%
from PIL import Image
import cv2

# %%
import glob
impath = glob.glob("Hat416/train/*.jpg")
# cv2.imread()
print(impath[1])

# %%
path = impath[4]

img = cv2.imread(path)
print(img.shape)
Image.open(path)

# %%
new_file = open("Hat500.txt","w")

cnt = 0
with open("Hat416/train/_annotations.txt",'r') as f:
    for i in range(500):
        line = f.readline()
        if not line: break
        path = os.path.join(os.getcwd(),"Hat416","train",line)
        
        if cnt == 16:
            print(path)
            break
        cnt+=1
        # new_file.write(path)
new_file.close()
f.close()
# Out:
# B:\jupyter\tensorflow-yolov4-tflite\Hat416\train\002580_jpg.rf.011b98186b474cc230a33d9b19d77a21.jpg 178,163,225,211,1 280,225,334,286,1

# %%
import os

# path = path.replace('\\' , '/')
# path = path.replace('B:' , '')
print(path)

import cv2
from PIL import Image
img = cv2.imread(path.split(' ')[0])
print(img.shape)
# Out:
# B:\jupyter\tensorflow-yolov4-tflite\Hat416\train\002580_jpg.rf.011b98186b474cc230a33d9b19d77a21.jpg 178,163,225,211,1 280,225,334,286,1
#
# (416, 416, 3)

# %%
boxes = path.split(' ')[1:]
print(boxes)
boxes[-1] = boxes[-1][:-1]
print(boxes)

# box = boxes[2]
for box in boxes:
    label = box.split(',')[4]
    start = [int(box.split(',')[0]), int(box.split(',')[1])]
    end = [int(box.split(',')[2]), int(box.split(',')[3])]

    print(start, end, label)
    if label == '1':
        rect = cv2.rectangle(img, start, end, (255,0,0), 2)
    elif label == '2':
        rect = cv2.rectangle(img, start, end, (0,255,0), 2)
    elif label == '0':
        rect = cv2.rectangle(img, start, end, (0,0,255), 2)

img_ = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
Image.fromarray(img_)
# Out:
# ['178,163,225,211,1', '280,225,334,286,1\n']
# ['178,163,225,211,1', '280,225,334,286,1']
# [178, 163] [225, 211] 1
# [280, 225] [334, 286] 1
# <PIL.Image.Image image mode=RGB size=416x416 at 0x158D9D49E88>

# %%
img
